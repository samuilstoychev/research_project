# %% [markdown]
# # AffectNet Validation Results

# %%
import pickle5 as pickle
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pandas as pd

# %%
# %cd ../experiments/affectnet/validation/
# Out:
# /Users/samuilstoychev/Desktop/research_project_repo/research_project/experiments/affectnet/validation

# %%
# !ls
# Out:
# val_affectnet_1842_gr.pkl   val_affectnet_1856_lr.pkl
# val_affectnet_1842_grd.pkl  val_affectnet_1856_none.pkl
# val_affectnet_1842_lgr.pkl  val_affectnet_1856_nr.pkl
# val_affectnet_1842_lgrd.pkl val_affectnet_2306_gr.pkl
# val_affectnet_1842_lr.pkl   val_affectnet_2306_grd.pkl
# val_affectnet_1842_none.pkl val_affectnet_2306_lgr.pkl
# val_affectnet_1842_nr.pkl   val_affectnet_2306_lgrd.pkl
# val_affectnet_1856_gr.pkl   val_affectnet_2306_lr.pkl
# val_affectnet_1856_grd.pkl  val_affectnet_2306_none.pkl
# val_affectnet_1856_lgr.pkl  val_affectnet_2306_nr.pkl
# val_affectnet_1856_lgrd.pkl

# %%
N_ITERATIONS = 2000
N_TASKS = 4
STRATEGIES = ["nr", "lr", "gr", "lgr", "grd", "lgrd"]
SEED = 1842

# %%
def get_val_data_for(replay_strategy): 
    file = open("val_affectnet_{}_{}.pkl".format(SEED, replay_strategy), 'rb')
    val = pickle.load(file)
    return val[0]

def get_train_data_for(replay_strategy): 
    file = open("val_affectnet_{}_{}.pkl".format(SEED, replay_strategy), 'rb')
    val = pickle.load(file)
    return val[1]

# %%
def get_final_accs(accs): 
    return list(map(lambda x: x[2], list(filter(lambda x: x[1] == N_ITERATIONS, accs))))

# %%
def arrange_by_tasks(accs):
    res = [[] for _ in range(N_TASKS)]
    for time in range(N_TASKS): 
        for task_number in range(time + 1):
            res[task_number].append(accs[time][task_number]) 
    return res

# %%
def get_all_results(): 
    results = [dict() for _ in range(N_TASKS)]
    for replay_strategy in STRATEGIES: 
        data = get_final_accs(get_val_data_for(replay_strategy))
        data = arrange_by_tasks(data)
        for i in range(N_TASKS): 
            results[i][replay_strategy] = data[i]
    return results

# %%
res = get_all_results()

INCLUDE_NONE = False
EXPONENTIAL_SCALE = False
fig, ax = plt.subplots(1,N_TASKS,sharey=True)
fig.set_figheight(5)
fig.set_figwidth(15)

for task_number in range(N_TASKS): 
    results = res[task_number]
    for strategy in results: 
        if strategy is not "none" or INCLUDE_NONE: 
            ax[task_number].plot(list(range(task_number + 1, N_TASKS + 1)), results[strategy], 
                                 "-o", label=strategy)
    
    if EXPONENTIAL_SCALE: 
        exp = lambda x: 128000**(x)
        log = lambda x: np.log(x)
        ax[task_number].set_yscale('function', functions=(exp, log))
    if task_number == 0: 
        ax[task_number].legend(loc="lower left")
    if INCLUDE_NONE: 
        ax[task_number].set_ylim(0.5, 0.85)
    else: 
        ax[task_number].set_ylim(0.5, 0.85)
    ax[task_number].set_xlim(0.9, 4.1)
    ax[task_number].xaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()

# %%
rows = [] 

for replay_strategy in STRATEGIES: 
    val_results = get_final_accs(get_val_data_for(replay_strategy)) 
    train_results = get_final_accs(get_train_data_for(replay_strategy)) 
    
    val_accs = [] 
    train_accs = [] 
    for task_number in range(len(val_results)): 
        val_accs.append(val_results[task_number][task_number])
        train_accs.append(train_results[task_number][task_number]) 
        diffs = [train_accs[i] - val_accs[i] for i in range(len(val_accs))]
    rows.append([replay_strategy, "train"] + train_accs) 
    rows.append([replay_strategy, "val"] + val_accs)
    rows.append([replay_strategy, "discrepancy"] + diffs)

# %%
pd.DataFrame(rows, columns=["Replay method", "Accuracy"] + ["T" + str(i) for i in range(1, N_TASKS + 1)])
# Out:
#    Replay method     Accuracy        T1        T2        T3        T4
# 0             nr        train  0.667600  0.806000  0.672533  0.697067
# 1             nr          val  0.643000  0.781000  0.650000  0.674000
# 2             nr  discrepancy  0.024600  0.025000  0.022533  0.023067
# 3             lr        train  0.667333  0.812400  0.665467  0.678000
# 4             lr          val  0.652000  0.796000  0.647000  0.667000
# 5             lr  discrepancy  0.015333  0.016400  0.018467  0.011000
# 6             gr        train  0.672667  0.806000  0.685467  0.695733
# 7             gr          val  0.650000  0.794000  0.654000  0.686000
# 8             gr  discrepancy  0.022667  0.012000  0.031467  0.009733
# 9            lgr        train  0.667733  0.796133  0.675600  0.649067
# 10           lgr          val  0.647000  0.792000  0.651000  0.635000
# 11           lgr  discrepancy  0.020733  0.004133  0.024600  0.014067
# 12           grd        train  0.672667  0.817200  0.685333  0.705867
# 13           grd          val  0.650000  0.800000  0.662000  0.690000
# 14           grd  discrepancy  0.022667  0.017200  0.023333  0.015867
# 15          lgrd        train  0.667733  0.809467  0.686800  0.705600
# 16          lgrd          val  0.647000  0.793000  0.663000  0.679000
# 17          lgrd  discrepancy  0.020733  0.016467  0.023800  0.026600
